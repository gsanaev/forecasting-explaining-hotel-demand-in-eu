# %% [markdown]
# # 📘 Notebook 2 — Feature Engineering for Hotel Demand Forecasting (2015–2025)
#
# This notebook builds upon the cleaned dataset to construct **temporal**, **macroeconomic**, and **lag-based features** for forecasting hotel demand across EU countries.
# It prepares a modeling-ready dataset that serves as the foundation for econometric and machine-learning analyses in **Notebook 3**.
#
# ---
#
# ### **Structure Overview**
#
# 0. Environment Setup
# 1. Load Dataset
# 2. Feature Engineering: Lag Variables
# 3. Feature Engineering: Month-on-Month (MoM) Changes
# 4. Temporal Features
# 5. Data Quality Check
# 6. Export Feature-Engineered Dataset
#
# ---
#
# **Input:**
# 📁 `../data/processed/hotel_clean.csv`
#
# **Output:**
# 📁 `../data/processed/hotel_features.csv`

# %%
# %% ===============================================================
# STEP 0 — ENVIRONMENT SETUP
# ===============================================================
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings("ignore")

plt.style.use("seaborn-v0_8-whitegrid")
sns.set_palette("viridis")

BASE_DIR = Path("..")
DATA_PROCESSED = BASE_DIR / "data" / "processed"

for path in [DATA_PROCESSED]:
    path.mkdir(parents=True, exist_ok=True)

print("✅ Environment setup complete.")
# Out:
# ✅ Environment setup complete.

# %%
# %% ===============================================================
# STEP 1 — LOAD DATASET
# Purpose: Load the cleaned hotel dataset produced in Notebook 1.
# ===============================================================

DATA_PATH = DATA_PROCESSED / "hotel_clean.csv"
df = pd.read_csv(DATA_PATH, parse_dates=["month"])

print(f"✅ Dataset loaded: {df.shape[0]:,} rows × {df.shape[1]} columns")
print(f"✅ Range: {df['month'].min().strftime('%Y-%m')} → {df['month'].max().strftime('%Y-%m')}")
print(f"✅ Countries: {df['region'].nunique()}")
# Out:
# ✅ Dataset loaded: 3,328 rows × 10 columns
# ✅ Range: 2015-01 → 2025-08
# ✅ Countries: 26

# %%
# %% ===============================================================
# STEP 2 — FEATURE ENGINEERING: LAG VARIABLES
# Purpose: Create lag features for selected exogenous variables (L = 1, 2, 3).
# ===============================================================

lag_features = [
    "log_gdp", 
    "unemployment_rate", 
    "turnover_index", 
    "weighted_stringency_index", 
    "eurusd", 
    "eurgbp"
]

for col in lag_features:
    for L in [1, 2, 3]:
        df[f"{col}_lag{L}"] = df.groupby("region")[col].shift(L)

print(f"✅ Added {len(lag_features)*3} lag features.")
# Out:
# ✅ Added 18 lag features.

# %%
# %% ===============================================================
# STEP 3 — FEATURE ENGINEERING: MONTH-ON-MONTH (MoM) CHANGES
# Purpose: Capture monthly growth dynamics.
# ===============================================================

mom_vars = ["log_gdp", "turnover_index"]

for col in mom_vars:
    df[f"{col}_mom"] = (
        df.groupby("region")[col].pct_change() * 100
    )

df.replace([np.inf, -np.inf], np.nan, inplace=True)

print(f"✅ Added {len(mom_vars)} MoM change features.")
# Out:
# ✅ Added 2 MoM change features.

# %%
# %% ===============================================================
# STEP 4 — TEMPORAL FEATURES
# Purpose: Extract time-based components to capture seasonality.
# ===============================================================

df["m"] = df["month"].dt.month
df["quarter"] = df["month"].dt.quarter

print("✅ Added time-based features (month, quarter).")
# Out:
# ✅ Added time-based features (month, quarter).

# %%
# %% ===============================================================
# STEP 5 — DATA QUALITY CHECK
# Purpose: Summarize missing values and basic descriptive stats..
# ===============================================================

# --- Missing values summary ---
missing_tbl = (
    df.isna()
    .sum()
    .reset_index()
    .rename(columns={"index": "column", 0: "missing_count"})
)
missing_tbl["missing_pct"] = (missing_tbl["missing_count"] / len(df) * 100).round(2)

print("✅ Missing Values Summary:")
display(missing_tbl.sort_values("missing_count", ascending=False).head(10))

# --- Quick numeric overview ---
print("\n✅ Numeric Feature Summary:")
display(df.describe().T.round(2))
# Out:
# ✅ Missing Values Summary:
#                             column  missing_count  missing_pct
# 18             turnover_index_lag3             78         2.34
# 27                     eurgbp_lag3             78         2.34
# 24                     eurusd_lag3             78         2.34
# 21  weighted_stringency_index_lag3             78         2.34
# 12                    log_gdp_lag3             78         2.34
# 15          unemployment_rate_lag3             78         2.34
# 20  weighted_stringency_index_lag2             52         1.56
# 14          unemployment_rate_lag2             52         1.56
# 17             turnover_index_lag2             52         1.56
# 26                     eurgbp_lag2             52         1.56
# ✅ Numeric Feature Summary:
#                                  count                 mean  \
# month                             3328  2020-05-15 15:22:30
# year                            3328.0           2019.84375
# log_nights_spent                3328.0            13.448212
# log_gdp                         3328.0            10.389093
# unemployment_rate               3328.0             6.672356
# turnover_index                  3328.0           119.753696
# weighted_stringency_index       3328.0             49.18058
# eurusd                          3328.0             1.118962
# eurgbp                          3328.0             0.849934
# log_gdp_lag1                    3302.0            10.388227
# log_gdp_lag2                    3276.0            10.387347
# log_gdp_lag3                    3250.0            10.386454
# unemployment_rate_lag1          3302.0             6.680103
# unemployment_rate_lag2          3276.0             6.689316
# unemployment_rate_lag3          3250.0             6.698338
# turnover_index_lag1             3302.0           118.916051
# turnover_index_lag2             3276.0           118.070513
# turnover_index_lag3             3250.0           117.339354
# weighted_stringency_index_lag1  3302.0             49.18058
# weighted_stringency_index_lag2  3276.0             49.18058
# weighted_stringency_index_lag3  3250.0             49.18058
# eurusd_lag1                     3302.0             1.118571
# eurusd_lag2                     3276.0             1.118377
# eurusd_lag3                     3250.0             1.117943
# eurgbp_lag1                     3302.0             0.849811
# eurgbp_lag2                     3276.0             0.849714
# eurgbp_lag3                     3250.0             0.849674
# log_gdp_mom                     3302.0              0.02541
# turnover_index_mom              3302.0             2.725155
# m                               3328.0                6.375
# quarter                         3328.0             2.460938
#
#                                                 min                  25%  \
# month                           2015-01-31 00:00:00  2017-09-22 12:00:00
# year                                         2015.0               2017.0
# log_nights_spent                           5.147494            12.100265
# log_gdp                                    7.427144             9.032616
# unemployment_rate                               2.0                  4.6
# turnover_index                                  6.3                 78.7
# weighted_stringency_index                 36.617093            44.671611
# eurusd                                     0.982956             1.084225
# eurgbp                                        0.701             0.842647
# log_gdp_lag1                               7.427144             9.032162
# log_gdp_lag2                               7.427144             9.031178
# log_gdp_lag3                               7.427144             9.029664
# unemployment_rate_lag1                          2.0                  4.6
# unemployment_rate_lag2                          2.0                  4.6
# unemployment_rate_lag3                          2.0                  4.6
# turnover_index_lag1                             6.3                77.75
# turnover_index_lag2                             6.3                 77.5
# turnover_index_lag3                             6.3               76.825
# weighted_stringency_index_lag1            36.617093            44.671611
# weighted_stringency_index_lag2            36.617093            44.671611
# weighted_stringency_index_lag3            36.617093            44.671611
# eurusd_lag1                                0.982956             1.083882
# eurusd_lag2                                0.982956             1.083882
# eurusd_lag3                                0.982956             1.083882
# eurgbp_lag1                                   0.701               0.8424
# eurgbp_lag2                                   0.701               0.8424
# eurgbp_lag3                                   0.701               0.8424
# log_gdp_mom                               -1.706215            -0.104293
# turnover_index_mom                       -86.123348            -4.107911
# m                                               1.0                  3.0
# quarter                                         1.0                  1.0
#
#                                                 50%                  75%  \
# month                           2020-05-15 12:00:00  2023-01-07 18:00:00
# year                                         2020.0              2022.25
# log_nights_spent                          13.632071            14.594523
# log_gdp                                   10.493316            11.423246
# unemployment_rate                               6.0                  7.7
# turnover_index                                114.5              155.525
# weighted_stringency_index                 48.849586             52.96561
# eurusd                                     1.115387             1.157142
# eurgbp                                     0.859745              0.88004
# log_gdp_lag1                               10.49297            11.421645
# log_gdp_lag2                                10.4924            11.420809
# log_gdp_lag3                              10.492111            11.420097
# unemployment_rate_lag1                          6.0                  7.7
# unemployment_rate_lag2                          6.0                  7.7
# unemployment_rate_lag3                          6.0                  7.7
# turnover_index_lag1                           114.5              154.275
# turnover_index_lag2                           114.5               153.35
# turnover_index_lag3                           114.5                151.9
# weighted_stringency_index_lag1            48.849586             52.96561
# weighted_stringency_index_lag2            48.849586             52.96561
# weighted_stringency_index_lag3            48.849586             52.96561
# eurusd_lag1                                1.115324             1.156136
# eurusd_lag2                                1.115281             1.156136
# eurusd_lag3                                1.115237             1.148765
# eurgbp_lag1                                 0.85974               0.8801
# eurgbp_lag2                                0.859085               0.8801
# eurgbp_lag3                                 0.85974               0.8801
# log_gdp_mom                                0.040795              0.16797
# turnover_index_mom                              0.0             8.815959
# m                                               6.0                  9.0
# quarter                                         2.0                  3.0
#
#                                                 max        std
# month                           2025-08-31 00:00:00        NaN
# year                                         2025.0   3.083779
# log_nights_spent                           17.22325   1.812729
# log_gdp                                   13.415018   1.561592
# unemployment_rate                              25.1   3.238143
# turnover_index                                419.6  56.704813
# weighted_stringency_index                 65.876549    6.46075
# eurusd                                     1.240957   0.051836
# eurgbp                                       0.9201   0.049174
# log_gdp_lag1                              13.415018   1.561746
# log_gdp_lag2                              13.415018   1.561903
# log_gdp_lag3                              13.415018   1.562062
# unemployment_rate_lag1                         25.1   3.244363
# unemployment_rate_lag2                         25.1   3.250812
# unemployment_rate_lag3                         25.1   3.256682
# turnover_index_lag1                           419.6   55.82482
# turnover_index_lag2                           419.6   54.91568
# turnover_index_lag3                           419.6  54.370249
# weighted_stringency_index_lag1            65.876549   6.460758
# weighted_stringency_index_lag2            65.876549   6.460766
# weighted_stringency_index_lag3            65.876549   6.460774
# eurusd_lag1                                1.240957   0.051851
# eurusd_lag2                                1.240957   0.052011
# eurusd_lag3                                1.240957    0.05199
# eurgbp_lag1                                  0.9201   0.049348
# eurgbp_lag2                                  0.9201   0.049531
# eurgbp_lag3                                  0.9201   0.049727
# log_gdp_mom                                0.783342   0.299955
# turnover_index_mom                        209.74026  19.862572
# m                                              12.0   3.426062
# quarter                                         4.0   1.110504

# %%
# %% ===============================================================
# STEP 6 — EXPORT FEATURE-ENGINEERED DATASET
# Purpose: Save all relevant columns as a modeling-ready dataset.
# ===============================================================

# --- Identify feature columns ---
lag_cols = [c for c in df.columns if "_lag" in c or "_mom" in c]

# --- Define export column order ---
export_cols = [
    "region", "month", "year", "log_nights_spent"
] + lag_cols + [
    "log_gdp", "unemployment_rate", "turnover_index",
    "weighted_stringency_index",
    "eurusd", "eurgbp"
]

# --- Create a clean feature DataFrame ---
df_features = df[export_cols].copy()

# --- Save feature-engineered dataset ---
FEATURE_PATH = DATA_PROCESSED / "hotel_features.csv"
df_features.to_csv(FEATURE_PATH, index=False)

# --- Confirm output ---
print(f"💾 Feature-engineered dataset saved → {FEATURE_PATH.resolve()}")
print(f"✅ Shape: {df_features.shape[0]} rows × {df_features.shape[1]} columns")
# Out:
# 💾 Feature-engineered dataset saved → /Users/golibsanaev/Library/CloudStorage/Dropbox/GitHub_gsanaev/forecasting-explaining-hotel-demand-in-eu/data/processed/hotel_features.csv
# ✅ Shape: 3328 rows × 30 columns

# %% [markdown]
# ## ✅ Summary
#
# Notebook 2 completed successfully.
# The feature-engineered dataset is ready for model training and evaluation in **Notebook 3 — Model Estimation and Comparison (Econometric + ML Models)**.
#
# ---
